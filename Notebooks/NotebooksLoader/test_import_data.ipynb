# %%
from MarketDataLoader.OptionDataFetcher import OptionDataFetcher,OptionMaturity

# Define the ticker symbol (e.g., Apple Inc.)
ticker = "AAPL"

AppleData = OptionDataFetcher(ticker)

# %%
0.95*5725.5
# Out:
# 5439.224999999999

# %%
AppleData.build_market()

# %%
AppleMaturities = AppleData.get_maturities()

# %%
AppleMaturities
# Out:
# ['2025-08-15',
#  '2025-08-22',
#  '2025-08-29',
#  '2025-09-05',
#  '2025-09-12',
#  '2025-09-19',
#  '2025-09-26',
#  '2025-10-17',
#  '2025-11-21',
#  '2025-12-19',
#  '2026-01-16',
#  '2026-02-20',
#  '2026-03-20',
#  '2026-05-15',
#  '2026-06-18',
#  '2026-09-18',
#  '2026-12-18',
#  '2027-01-15',
#  '2027-06-17',
#  '2027-12-17']

# %%
maturity = AppleMaturities[5]
options = AppleData.get_maturity_data(AppleMaturities[7])

# %%
AppleOptionsMaturity = OptionMaturity(expiry=maturity, calls = options.calls, puts = options.puts, spot_price=options.spot_price)

# %%
# Out:
#    expiry_date  days_to_expiry    B0T  zero_rate
# 0   2025-08-15               2  0.996   0.731965
# 1   2025-08-22               9  0.992   0.325972
# 2   2025-08-29              16  0.998   0.045702
# 3   2025-09-05              23  1.046  -0.714197
# 4   2025-09-12              30  1.012  -0.145230
# 5   2025-09-19              37  1.024  -0.234121
# 6   2025-09-26              44  0.972   0.235748
# 7   2025-10-17              65  0.952   0.276411
# 8   2025-11-21             100  1.024  -0.086625
# 9   2025-12-19             128  0.936   0.188731
# 10  2026-01-16             156  0.966   0.080991
# 11  2026-02-20             191  1.022  -0.041615
# 12  2026-03-20             219  0.899   0.177575
# 13  2026-05-15             275  1.010  -0.013216
# 14  2026-06-18             309  0.896   0.129805
# 15  2026-09-18             401  1.032  -0.028690
# 16  2026-12-18             492  0.995   0.003721
# 17  2027-01-15             520  1.025  -0.017344
# 18  2027-06-17             673  1.022  -0.011810
# 19  2027-12-17             856  0.774   0.109312

# %%
AppleOptionsMaturity.plot_smile(option_type = "call", x_axis = 'moneyness')

# %%
AppleOptionsMaturity.plot_smile(option_type = "put", x_axis = 'moneyness')

# %%
AppleOptionsMaturity.plot_smile(option_type = "OTM", x_axis = 'moneyness')

# %%
AppleOptionsMaturity.estimate_forward()
# Out:
# 228.84453781512605

# %%
AppleData.plot_forward_curve()

# %%
AppleData.get_forward(1)
# Out:
# 235.6292242946218
